# %%
import requests
import pandas as pd
from datetime import datetime

API_KEY = "df57c152a532b88aa2501d0141e9f090"

cities = ["Delhi", "Mumbai", "Kolkata", "Chennai", "Bangalore"]

weather_records = []

for city in cities:
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={API_KEY}&units=metric"
    response = requests.get(url)
    data = response.json()

    weather_records.append({
        "city": city,
        "temperature": data["main"]["temp"],
        "humidity": data["main"]["humidity"],
        "pressure": data["main"]["pressure"],
        "wind_speed": data["wind"]["speed"],
        "weather": data["weather"][0]["main"],
        "timestamp": datetime.now()
    })

df = pd.DataFrame(weather_records)
df.to_csv("../data/raw_weather_data.csv", index=False)

print("✅ Real weather dataset saved as CSV")
# Out:
# ✅ Real weather dataset saved as CSV
